# %%
# !pip list
# Out:
# Package                                  Version         Editable project location
# ---------------------------------------- --------------- ------------------------------------------------------------------------------------------------------------------------
# absl-py                                  2.0.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.4.4
# aiohttp                                  3.10.11
# aiohttp-retry                            2.8.3
# aiosignal                                1.3.1
# alabaster                                0.7.12
# alembic                                  1.11.1
# altair                                   5.2.0
# amqp                                     5.1.1
# anaconda-client                          1.11.1
# anaconda-navigator                       2.4.0
# anaconda-project                         0.11.1
# annotated-types                          0.7.0
# ...

# %%
# !pip uninstall chromadb 0.6.3

# %%
# !pip install --upgrade chromadb

# %%
pip uninstall  langchain

# %%
#!pip uninstall  openai

# %%
from git import Repo
from langchain.text_splitter import Language
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import LanguageParser
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationSummaryMemory
from langchain.chains import ConversationalRetrievalChain
from openai import OpenAI

# %%
"""
# !pip install langchain==0.0.
# !pip install python-dotenv
# !pip install  GitPython
# !pip install openai==0.28
# !pip install chromadb==0.4.4
# !pip install chromadb
"""

# %%
# %pwd

# %%
# !mkdir test_repor
# %ls -lrt

# %%
# %ls

# %%
repo_path = "test_repo/"

repo = Repo.clone_from("https://github.com/entbappy/End-to-end-Medical-Chatbot-Generative-AI", to_path=repo_path)

# %%
loader = GenericLoader.from_filesystem(repo_path,
                                        glob = "**/*",
                                       suffixes=[".py"],
                                       parser = LanguageParser(language=Language.PYTHON, parser_threshold=500)
)

# %%
documnets=loader.load()

# %%
documnets

# %%
len(documnets)

# %%
documnets[0].page_content

# %%
documents_splitter = RecursiveCharacterTextSplitter.from_language(language = Language.PYTHON,
                                                             chunk_size = 500,
                                                             chunk_overlap = 20)

# %%
texts=documents_splitter.split_documents(documnets)

# %%
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY=os.environ.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY']=OPENAI_API_KEY

# %%
type(texts[0].page_content)

# %%
load_dotenv()

OPENAI_API_KEY=os.environ.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY']=OPENAI_API_KEY

# %%
embeddings=OpenAIEmbeddings(disallowed_special=())

# %%
llm=OpenAI()

# %%
pip uninstall langchain

# %%
 
chromadb==0.4.4
langchain==0.0.249

# %%
vectordb = Chroma.from_documents(texts, embedding=embeddings, persist_directory='./db1')

# %%
vectordb.persist()

# %%
vectordb
